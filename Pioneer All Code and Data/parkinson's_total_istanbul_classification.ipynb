# %% [markdown]
# ---
# ### Import Libraries

# %%
# !pip install pycaret

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pycaret.classification import *

from sklearn.metrics import *
import scikitplot as skplt

df = pd.read_csv("pd_speech_features.csv")
# Out:
# Requirement already satisfied: pycaret in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (3.0.3)
# Requirement already satisfied: numpy<1.24,>=1.21 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.21.5)
# Requirement already satisfied: pyod>=1.0.8 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: numba>=0.55.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.55.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.5.2)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.3.5)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.3)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (6.7.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.3.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.10.1)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: scipy<2.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.9.1)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.6.1)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.8.3.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: cloudpickle in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: xxhash in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: wurlitzer in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.20.0)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.0.1)
# Requirement already satisfied: tbats>=1.1.3 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: jinja2>=1.2 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.11.3)
# Requirement already satisfied: requests>=2.27.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: ipython>=5.5.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (7.31.1)
# Requirement already satisfied: psutil>=5.9.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: plotly>=5.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: schemdraw==0.15 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.5)
# Requirement already satisfied: patsy>=0.5.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: packaging in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from deprecation>=2.1.0->pycaret) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.8.0)
# Requirement already satisfied: pexpect>4.3 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: decorator in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: pygments in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: backcall in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: appnope in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (63.4.1)
# Requirement already satisfied: traitlets>=4.2 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (6.15.2)
# Requirement already satisfied: wheel in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from lightgbm>=3.0.0->pycaret) (0.37.1)
# Requirement already satisfied: cycler>=0.10 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (4.25.0)
# Requirement already satisfied: jsonschema>=2.6 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.16.0)
# Requirement already satisfied: jupyter_core in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (4.11.1)
# Requirement already satisfied: fastjsonschema in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from numba>=0.55.0->pycaret) (0.38.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.1)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.4.2)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.11.0)
# Requirement already satisfied: trace-updater>=0.0.8 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.0.9.1)
# Requirement already satisfied: urllib3 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.11)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (0.29.32)
# Requirement already satisfied: six in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: scikit-base<0.6.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (0.5.0)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: Flask<2.3.0,>=1.0.4 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.1.2)
# Requirement already satisfied: retrying in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<2.3.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.3)
# Requirement already satisfied: nest-asyncio in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.5)
# Requirement already satisfied: ansi2html in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (4.3.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,>=0.16.1->pycaret) (1.14.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: tornado>=6.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: pyzmq>=17 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (21.4.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.12)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=5.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from Flask<2.3.0,>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: argon2-cffi in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.13.1)
# Requirement already satisfied: prometheus-client in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.4)
# Requirement already satisfied: bleach in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: testpath in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.6.0)
# Requirement already satisfied: defusedxml in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: argon2-cffi-bindings in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.1)
# Requirement already satisfied: webencodings in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: pycparser in /Users/rishithprathi/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# 2          0.008340            0.000060       0.00176  ...
# 3          0.010858            0.000183       0.00419  ...
# 4          0.008162            0.002669       0.00535  ...
#
#    tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                     1.5620                     2.6445
# 1                     1.5589                     3.6107
# 2                     1.5643                     2.3308
# 3                     3.7805                     3.5664
# 4                     6.1727                     5.8416
#
#    tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 0                     3.8686                     4.2105
# 1                    23.5155                    14.1962
# 2                     9.4959                    10.7458
# 3                     5.2558                    14.0403
# 4                     6.0805                     5.7621
#
#    tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 0                     5.1221                     4.4625
# 1                    11.0261                     9.5082
# 2                    11.0177                     4.8066
# 3                     4.2235                     4.6857
# 4                     7.7817                    11.6891
#
#    tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 0                     2.6202                     3.0004
# 1                     6.5245                     6.3431
# 2                     2.9199                     3.1495
# 3                     4.8460                     6.2650
# 4                     8.2103                     5.0559
#
#    tqwt_kurtosisValue_dec_36  class
# 0                    18.9405      1
# 1                    45.1780      1
# 2                     4.7666      1
# 3                     4.0603      1
# 4                     6.1164      1
#
# [5 rows x 755 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Columns: 755 entries, id to class
# dtypes: float64(749), int64(6)
# memory usage: 4.4 MB

# %%
df.describe()
# Out:
#                id      gender         PPE         DFA        RPDE   numPulses  \
# count  756.000000  756.000000  756.000000  756.000000  756.000000  756.000000
# mean   125.500000    0.515873    0.746284    0.700414    0.489058  323.972222
# std     72.793721    0.500079    0.169294    0.069718    0.137442   99.219059
# min      0.000000    0.000000    0.041551    0.543500    0.154300    2.000000
# 25%     62.750000    0.000000    0.762833    0.647053    0.386537  251.000000
# 50%    125.500000    1.000000    0.809655    0.700525    0.484355  317.000000
# 75%    188.250000    1.000000    0.834315    0.754985    0.586515  384.250000
# max    251.000000    1.000000    0.907660    0.852640    0.871230  907.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        756.000000        756.000000          756.000000    756.000000
# mean         322.678571          0.006360            0.000383      0.002324
# std           99.402499          0.001826            0.000728      0.002628
# min            1.000000          0.002107            0.000011      0.000210
# 25%          250.000000          0.005003            0.000049      0.000970
# 50%          316.000000          0.006048            0.000077      0.001495
# 75%          383.250000          0.007528            0.000171      0.002520
# max          905.000000          0.012966            0.003483      0.027750
#
#        ...  tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# count  ...                 756.000000                 756.000000
# mean   ...                  26.237251                  22.840337
# std    ...                  42.220693                  32.626464
# min    ...                   1.509800                   1.531700
# 25%    ...                   2.408675                   3.452800
# 50%    ...                   5.586300                   7.062750
# 75%    ...                  28.958075                  29.830850
# max    ...                 239.788800                 203.311300
#
#        tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# count                 756.000000                 756.000000
# mean                   18.587888                  13.872018
# std                    25.537464                  20.046029
# min                     1.582900                   1.747200
# 25%                     3.354825                   3.077450
# 50%                     6.077400                   4.770850
# 75%                    21.944050                  13.188000
# max                   121.542900                 102.207000
#
#        tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# count                 756.000000                 756.000000
# mean                   12.218953                  12.375335
# std                    17.783642                  16.341665
# min                     1.789500                   1.628700
# 25%                     2.937025                   3.114375
# 50%                     4.300450                   4.741450
# 75%                    10.876150                  12.201325
# max                    85.571700                  73.532200
#
#        tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# count                 756.000000                 756.000000
# mean                   14.799230                  14.751559
# std                    15.722502                  14.432979
# min                     1.861700                   1.955900
# 25%                     3.665925                   3.741275
# 50%                     6.725700                   7.334250
# 75%                    21.922050                  22.495175
# max                    62.007300                  57.544300
#
#        tqwt_kurtosisValue_dec_36       class
# count                 756.000000  756.000000
# mean                   31.481110    0.746032
# std                    34.230991    0.435568
# min                     2.364000    0.000000
# 25%                     3.948750    0.000000
# 50%                    10.637250    1.000000
# 75%                    61.125325    1.000000
# max                   156.423700    1.000000
#
# [8 rows x 755 columns]

# %%
ax = sns.countplot(x="class", data=df)

# %% [markdown]
# ### Split training & test dataset

# %%
test_df = df.sample(frac=0.1)
train_df = df.drop(test_df.index).reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

test_df['set'] = 'test'
train_df['set'] = 'train'

ax = sns.catplot(x="class", col="set", data=pd.concat([train_df, test_df]), kind="count", height=3)
plt.show()

print('Training dataset           :', len(train_df))
print('Unseen data for validation :', len(test_df))
# Out:
# Training dataset           : 680
# Unseen data for validation : 76

# %% [markdown]
# ### Setup environment

# %%
clf1 = setup(data = train_df, target = 'class',ignore_features = ['id'], fix_imbalance=True, session_id=123, remove_outliers = True)
# Out:
# <style type="text/css">
# #T_a724d_row10_col1, #T_a724d_row16_col1, #T_a724d_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a724d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a724d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a724d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a724d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a724d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a724d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a724d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a724d_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a724d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_a724d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a724d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_a724d_row3_col1" class="data row3 col1" >(680, 756)</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a724d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_a724d_row4_col1" class="data row4 col1" >(879, 755)</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a724d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_a724d_row5_col1" class="data row5 col1" >(674, 755)</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a724d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_a724d_row6_col1" class="data row6 col1" >(205, 755)</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a724d_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_a724d_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a724d_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_a724d_row8_col1" class="data row8 col1" >753</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a724d_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_a724d_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a724d_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_a724d_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a724d_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_a724d_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a724d_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_a724d_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a724d_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_a724d_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a724d_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_a724d_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a724d_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_a724d_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a724d_row16_col0" class="data row16 col0" >Remove outliers</td>
#       <td id="T_a724d_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a724d_row17_col0" class="data row17 col0" >Outliers threshold</td>
#       <td id="T_a724d_row17_col1" class="data row17 col1" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_a724d_row18_col0" class="data row18 col0" >Fix imbalance</td>
#       <td id="T_a724d_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_a724d_row19_col0" class="data row19 col0" >Fix imbalance method</td>
#       <td id="T_a724d_row19_col1" class="data row19 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_a724d_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_a724d_row20_col1" class="data row20 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_a724d_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_a724d_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_a724d_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_a724d_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_a724d_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_a724d_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_a724d_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_a724d_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_a724d_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_a724d_row25_col1" class="data row25 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a724d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_a724d_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_a724d_row26_col1" class="data row26 col1" >be38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model selection

# %%
compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         14:30:30
# Status              Compiling Final Models
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_a009c th {
#   text-align: left;
# }
# #T_a009c_row0_col0, #T_a009c_row0_col1, #T_a009c_row0_col2, #T_a009c_row0_col3, #T_a009c_row0_col4, #T_a009c_row0_col5, #T_a009c_row0_col6, #T_a009c_row0_col7, #T_a009c_row0_col8, #T_a009c_row1_col0, #T_a009c_row1_col1, #T_a009c_row1_col2, #T_a009c_row1_col3, #T_a009c_row1_col4, #T_a009c_row1_col5, #T_a009c_row1_col6, #T_a009c_row1_col7, #T_a009c_row1_col8, #T_a009c_row2_col0, #T_a009c_row2_col1, #T_a009c_row2_col2, #T_a009c_row2_col3, #T_a009c_row2_col4, #T_a009c_row2_col5, #T_a009c_row2_col6, #T_a009c_row2_col7, #T_a009c_row2_col8, #T_a009c_row3_col0, #T_a009c_row3_col1, #T_a009c_row3_col2, #T_a009c_row3_col3, #T_a009c_row3_col4, #T_a009c_row3_col5, #T_a009c_row3_col6, #T_a009c_row3_col7, #T_a009c_row3_col8, #T_a009c_row4_col0, #T_a009c_row4_col1, #T_a009c_row4_col2, #T_a009c_row4_col3, #T_a009c_row4_col4, #T_a009c_row4_col5, #T_a009c_row4_col6, #T_a009c_row4_col7, #T_a009c_row4_col8, #T_a009c_row5_col0, #T_a009c_row5_col1, #T_a009c_row5_col2, #T_a009c_row5_col3, #T_a009c_row5_col4, #T_a009c_row5_col5, #T_a009c_row5_col6, #T_a009c_row5_col7, #T_a009c_row5_col8, #T_a009c_row6_col0, #T_a009c_row6_col1, #T_a009c_row6_col2, #T_a009c_row6_col3, #T_a009c_row6_col4, #T_a009c_row6_col5, #T_a009c_row6_col6, #T_a009c_row6_col7, #T_a009c_row6_col8, #T_a009c_row7_col0, #T_a009c_row7_col1, #T_a009c_row7_col2, #T_a009c_row7_col3, #T_a009c_row7_col4, #T_a009c_row7_col5, #T_a009c_row7_col6, #T_a009c_row7_col7, #T_a009c_row7_col8, #T_a009c_row8_col0, #T_a009c_row8_col1, #T_a009c_row8_col2, #T_a009c_row8_col3, #T_a009c_row8_col4, #T_a009c_row8_col5, #T_a009c_row8_col6, #T_a009c_row8_col7, #T_a009c_row8_col8, #T_a009c_row9_col0, #T_a009c_row9_col1, #T_a009c_row9_col2, #T_a009c_row9_col3, #T_a009c_row9_col4, #T_a009c_row9_col5, #T_a009c_row9_col6, #T_a009c_row9_col7, #T_a009c_row9_col8, #T_a009c_row10_col0, #T_a009c_row10_col1, #T_a009c_row10_col2, #T_a009c_row10_col3, #T_a009c_row10_col4, #T_a009c_row10_col5, #T_a009c_row10_col6, #T_a009c_row10_col7, #T_a009c_row10_col8, #T_a009c_row11_col0, #T_a009c_row11_col1, #T_a009c_row11_col2, #T_a009c_row11_col3, #T_a009c_row11_col4, #T_a009c_row11_col5, #T_a009c_row11_col6, #T_a009c_row11_col7, #T_a009c_row11_col8, #T_a009c_row12_col0, #T_a009c_row12_col1, #T_a009c_row12_col2, #T_a009c_row12_col3, #T_a009c_row12_col4, #T_a009c_row12_col5, #T_a009c_row12_col6, #T_a009c_row12_col7, #T_a009c_row12_col8, #T_a009c_row13_col0, #T_a009c_row13_col1, #T_a009c_row13_col2, #T_a009c_row13_col3, #T_a009c_row13_col4, #T_a009c_row13_col5, #T_a009c_row13_col6, #T_a009c_row13_col7, #T_a009c_row13_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_a009c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a009c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a009c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a009c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a009c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a009c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a009c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a009c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a009c_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a009c_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a009c_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_a009c_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a009c_row0_col1" class="data row0 col1" >0.8779</td>
#       <td id="T_a009c_row0_col2" class="data row0 col2" >0.9255</td>
#       <td id="T_a009c_row0_col3" class="data row0 col3" >0.9551</td>
#       <td id="T_a009c_row0_col4" class="data row0 col4" >0.8933</td>
#       <td id="T_a009c_row0_col5" class="data row0 col5" >0.9218</td>
#       <td id="T_a009c_row0_col6" class="data row0 col6" >0.6400</td>
#       <td id="T_a009c_row0_col7" class="data row0 col7" >0.6626</td>
#       <td id="T_a009c_row0_col8" class="data row0 col8" >3.1900</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_a009c_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_a009c_row1_col1" class="data row1 col1" >0.8738</td>
#       <td id="T_a009c_row1_col2" class="data row1 col2" >0.9232</td>
#       <td id="T_a009c_row1_col3" class="data row1 col3" >0.9495</td>
#       <td id="T_a009c_row1_col4" class="data row1 col4" >0.8904</td>
#       <td id="T_a009c_row1_col5" class="data row1 col5" >0.9184</td>
#       <td id="T_a009c_row1_col6" class="data row1 col6" >0.6389</td>
#       <td id="T_a009c_row1_col7" class="data row1 col7" >0.6516</td>
#       <td id="T_a009c_row1_col8" class="data row1 col8" >1.1830</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_a009c_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_a009c_row2_col1" class="data row2 col1" >0.8592</td>
#       <td id="T_a009c_row2_col2" class="data row2 col2" >0.9097</td>
#       <td id="T_a009c_row2_col3" class="data row2 col3" >0.9298</td>
#       <td id="T_a009c_row2_col4" class="data row2 col4" >0.8891</td>
#       <td id="T_a009c_row2_col5" class="data row2 col5" >0.9084</td>
#       <td id="T_a009c_row2_col6" class="data row2 col6" >0.6021</td>
#       <td id="T_a009c_row2_col7" class="data row2 col7" >0.6094</td>
#       <td id="T_a009c_row2_col8" class="data row2 col8" >1.5090</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_a009c_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a009c_row3_col1" class="data row3 col1" >0.8527</td>
#       <td id="T_a009c_row3_col2" class="data row3 col2" >0.9152</td>
#       <td id="T_a009c_row3_col3" class="data row3 col3" >0.9044</td>
#       <td id="T_a009c_row3_col4" class="data row3 col4" >0.9032</td>
#       <td id="T_a009c_row3_col5" class="data row3 col5" >0.9017</td>
#       <td id="T_a009c_row3_col6" class="data row3 col6" >0.6011</td>
#       <td id="T_a009c_row3_col7" class="data row3 col7" >0.6155</td>
#       <td id="T_a009c_row3_col8" class="data row3 col8" >6.6000</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_a009c_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_a009c_row4_col1" class="data row4 col1" >0.8251</td>
#       <td id="T_a009c_row4_col2" class="data row4 col2" >0.8842</td>
#       <td id="T_a009c_row4_col3" class="data row4 col3" >0.8848</td>
#       <td id="T_a009c_row4_col4" class="data row4 col4" >0.8852</td>
#       <td id="T_a009c_row4_col5" class="data row4 col5" >0.8834</td>
#       <td id="T_a009c_row4_col6" class="data row4 col6" >0.5288</td>
#       <td id="T_a009c_row4_col7" class="data row4 col7" >0.5360</td>
#       <td id="T_a009c_row4_col8" class="data row4 col8" >2.1300</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_a009c_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_a009c_row5_col1" class="data row5 col1" >0.7665</td>
#       <td id="T_a009c_row5_col2" class="data row5 col2" >0.7101</td>
#       <td id="T_a009c_row5_col3" class="data row5 col3" >0.8233</td>
#       <td id="T_a009c_row5_col4" class="data row5 col4" >0.8620</td>
#       <td id="T_a009c_row5_col5" class="data row5 col5" >0.8407</td>
#       <td id="T_a009c_row5_col6" class="data row5 col6" >0.3994</td>
#       <td id="T_a009c_row5_col7" class="data row5 col7" >0.4061</td>
#       <td id="T_a009c_row5_col8" class="data row5 col8" >0.9050</td>
#     </tr>
#     <tr>
#       <th id="T_a009c_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_a009c_r
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %% [markdown]
# ### Create Extra Trees Classifier Model

# %%
extraTreesClassifier = create_model('et')
# Out:
# <style type="text/css">
# #T_c3169_row10_col0, #T_c3169_row10_col1, #T_c3169_row10_col2, #T_c3169_row10_col3, #T_c3169_row10_col4, #T_c3169_row10_col5, #T_c3169_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c3169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3169_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c3169_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c3169_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c3169_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c3169_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c3169_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c3169_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3169_row0_col0" class="data row0 col0" >0.8750</td>
#       <td id="T_c3169_row0_col1" class="data row0 col1" >0.9213</td>
#       <td id="T_c3169_row0_col2" class="data row0 col2" >0.9444</td>
#       <td id="T_c3169_row0_col3" class="data row0 col3" >0.8947</td>
#       <td id="T_c3169_row0_col4" class="data row0 col4" >0.9189</td>
#       <td id="T_c3169_row0_col5" class="data row0 col5" >0.6471</td>
#       <td id="T_c3169_row0_col6" class="data row0 col6" >0.6516</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3169_row1_col0" class="data row1 col0" >0.8333</td>
#       <td id="T_c3169_row1_col1" class="data row1 col1" >0.8762</td>
#       <td id="T_c3169_row1_col2" class="data row1 col2" >0.8889</td>
#       <td id="T_c3169_row1_col3" class="data row1 col3" >0.8889</td>
#       <td id="T_c3169_row1_col4" class="data row1 col4" >0.8889</td>
#       <td id="T_c3169_row1_col5" class="data row1 col5" >0.5556</td>
#       <td id="T_c3169_row1_col6" class="data row1 col6" >0.5556</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3169_row2_col0" class="data row2 col0" >0.9167</td>
#       <td id="T_c3169_row2_col1" class="data row2 col1" >0.9209</td>
#       <td id="T_c3169_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_c3169_row2_col3" class="data row2 col3" >0.8974</td>
#       <td id="T_c3169_row2_col4" class="data row2 col4" >0.9459</td>
#       <td id="T_c3169_row2_col5" class="data row2 col5" >0.7664</td>
#       <td id="T_c3169_row2_col6" class="data row2 col6" >0.7882</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3169_row3_col0" class="data row3 col0" >0.7917</td>
#       <td id="T_c3169_row3_col1" class="data row3 col1" >0.8912</td>
#       <td id="T_c3169_row3_col2" class="data row3 col2" >0.9143</td>
#       <td id="T_c3169_row3_col3" class="data row3 col3" >0.8205</td>
#       <td id="T_c3169_row3_col4" class="data row3 col4" >0.8649</td>
#       <td id="T_c3169_row3_col5" class="data row3 col5" >0.4161</td>
#       <td id="T_c3169_row3_col6" class="data row3 col6" >0.4279</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3169_row4_col0" class="data row4 col0" >0.9167</td>
#       <td id="T_c3169_row4_col1" class="data row4 col1" >0.9462</td>
#       <td id="T_c3169_row4_col2" class="data row4 col2" >0.9429</td>
#       <td id="T_c3169_row4_col3" class="data row4 col3" >0.9429</td>
#       <td id="T_c3169_row4_col4" class="data row4 col4" >0.9429</td>
#       <td id="T_c3169_row4_col5" class="data row4 col5" >0.7890</td>
#       <td id="T_c3169_row4_col6" class="data row4 col6" >0.7890</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3169_row5_col0" class="data row5 col0" >0.9149</td>
#       <td id="T_c3169_row5_col1" class="data row5 col1" >0.9298</td>
#       <td id="T_c3169_row5_col2" class="data row5 col2" >0.9714</td>
#       <td id="T_c3169_row5_col3" class="data row5 col3" >0.9189</td>
#       <td id="T_c3169_row5_col4" class="data row5 col4" >0.9444</td>
#       <td id="T_c3169_row5_col5" class="data row5 col5" >0.7632</td>
#       <td id="T_c3169_row5_col6" class="data row5 col6" >0.7686</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3169_row6_col0" class="data row6 col0" >0.9149</td>
#       <td id="T_c3169_row6_col1" class="data row6 col1" >0.9714</td>
#       <td id="T_c3169_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_c3169_row6_col3" class="data row6 col3" >0.8974</td>
#       <td id="T_c3169_row6_col4" class="data row6 col4" >0.9459</td>
#       <td id="T_c3169_row6_col5" class="data row6 col5" >0.7487</td>
#       <td id="T_c3169_row6_col6" class="data row6 col6" >0.7735</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3169_row7_col0" class="data row7 col0" >0.8936</td>
#       <td id="T_c3169_row7_col1" class="data row7 col1" >0.9119</td>
#       <td id="T_c3169_row7_col2" class="data row7 col2" >1.0000</td>
#       <td id="T_c3169_row7_col3" class="data row7 col3" >0.8750</td>
#       <td id="T_c3169_row7_col4" class="data row7 col4" >0.9333</td>
#       <td id="T_c3169_row7_col5" class="data row7 col5" >0.6759</td>
#       <td id="T_c3169_row7_col6" class="data row7 col6" >0.7144</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3169_row8_col0" class="data row8 col0" >0.9149</td>
#       <td id="T_c3169_row8_col1" class="data row8 col1" >0.9631</td>
#       <td id="T_c3169_row8_col2" class="data row8 col2" >0.9429</td>
#       <td id="T_c3169_row8_col3" class="data row8 col3" >0.9429</td>
#       <td id="T_c3169_row8_col4" class="data row8 col4" >0.9429</td>
#       <td id="T_c3169_row8_col5" class="data row8 col5" >0.7762</td>
#       <td id="T_c3169_row8_col6" class="data row8 col6" >0.7762</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3169_row9_col0" class="data row9 col0" >0.8511</td>
#       <td id="T_c3169_row9_col1" class="data row9 col1" >0.8786</td>
#       <td id="T_c3169_row9_col2" class="data row9 col2" >0.9714</td>
#       <td id="T_c3169_row9_col3" class="data row9 col3" >0.8500</td>
#       <td id="T_c3169_row9_col4" class="data row9 col4" >0.9067</td>
#       <td id="T_c3169_row9_col5" class="data row9 col5" >0.5462</td>
#       <td id="T_c3169_row9_col6" class="data row9 col6" >0.5774</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c3169_row10_col0" class="data row10 col0" >0.8823</td>
#       <td id="T_c3169_row10_col1" class="data row10 col1" >0.9210</td>
#       <td id="T_c3169_row10_col2" class="data row10 col2" >0.9576</td>
#       <td id="T_c3169_row10_col3" class="data row10 col3" >0.8929</td>
#       <td id="T_c3169_row10_col4" class="data row10 col4" >0.9235</td>
#       <td id="T_c3169_row10_col5" class="data row10 col5" >0.6684</td>
#       <td id="T_c3169_row10_col6" class="data row10 col6" >0.6822</td>
#     </tr>
#     <tr>
#       <th id="T_c3169_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c3169_row11_col0" class="data row11 col0" >0.0416</td>
#       <td id="T_c3169_row11_col1" class="data row11 col1" >0.0313</td>
#       <td id="T_c3169_row11_col2" class="data row11 col2" >0.0360</td>
#       <td id="T_c3169_row11_col3" class="data row11 col3" >0.0362</td>
#       <td id="T_c3169_row11_col4
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %% [markdown]
# ### Tuned Model

# %%
tuned_extraTreesClassifier = tune_model(extraTreesClassifier)
# Out:
# <style type="text/css">
# #T_c8c0c_row10_col0, #T_c8c0c_row10_col1, #T_c8c0c_row10_col2, #T_c8c0c_row10_col3, #T_c8c0c_row10_col4, #T_c8c0c_row10_col5, #T_c8c0c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_c8c0c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8c0c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_c8c0c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_c8c0c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_c8c0c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_c8c0c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_c8c0c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_c8c0c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c0c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8c0c_row0_col0" class="data row0 col0" >0.8333</td>
#       <td id="T_c8c0c_row0_col1" class="data row0 col1" >0.9190</td>
#       <td id="T_c8c0c_row0_col2" class="data row0 col2" >0.8611</td>
#       <td id="T_c8c0c_row0_col3" class="data row0 col3" >0.9118</td>
#       <td id="T_c8c0c_row0_col4" class="data row0 col4" >0.8857</td>
#       <td id="T_c8c0c_row0_col5" class="data row0 col5" >0.5789</td>
#       <td id="T_c8c0c_row0_col6" class="data row0 col6" >0.5822</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8c0c_row1_col0" class="data row1 col0" >0.8542</td>
#       <td id="T_c8c0c_row1_col1" class="data row1 col1" >0.9560</td>
#       <td id="T_c8c0c_row1_col2" class="data row1 col2" >0.8333</td>
#       <td id="T_c8c0c_row1_col3" class="data row1 col3" >0.9677</td>
#       <td id="T_c8c0c_row1_col4" class="data row1 col4" >0.8955</td>
#       <td id="T_c8c0c_row1_col5" class="data row1 col5" >0.6585</td>
#       <td id="T_c8c0c_row1_col6" class="data row1 col6" >0.6790</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8c0c_row2_col0" class="data row2 col0" >0.8958</td>
#       <td id="T_c8c0c_row2_col1" class="data row2 col1" >0.9473</td>
#       <td id="T_c8c0c_row2_col2" class="data row2 col2" >0.9143</td>
#       <td id="T_c8c0c_row2_col3" class="data row2 col3" >0.9412</td>
#       <td id="T_c8c0c_row2_col4" class="data row2 col4" >0.9275</td>
#       <td id="T_c8c0c_row2_col5" class="data row2 col5" >0.7425</td>
#       <td id="T_c8c0c_row2_col6" class="data row2 col6" >0.7435</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8c0c_row3_col0" class="data row3 col0" >0.7917</td>
#       <td id="T_c8c0c_row3_col1" class="data row3 col1" >0.8637</td>
#       <td id="T_c8c0c_row3_col2" class="data row3 col2" >0.8286</td>
#       <td id="T_c8c0c_row3_col3" class="data row3 col3" >0.8788</td>
#       <td id="T_c8c0c_row3_col4" class="data row3 col4" >0.8529</td>
#       <td id="T_c8c0c_row3_col5" class="data row3 col5" >0.4969</td>
#       <td id="T_c8c0c_row3_col6" class="data row3 col6" >0.4994</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8c0c_row4_col0" class="data row4 col0" >0.8333</td>
#       <td id="T_c8c0c_row4_col1" class="data row4 col1" >0.9319</td>
#       <td id="T_c8c0c_row4_col2" class="data row4 col2" >0.8286</td>
#       <td id="T_c8c0c_row4_col3" class="data row4 col3" >0.9355</td>
#       <td id="T_c8c0c_row4_col4" class="data row4 col4" >0.8788</td>
#       <td id="T_c8c0c_row4_col5" class="data row4 col5" >0.6152</td>
#       <td id="T_c8c0c_row4_col6" class="data row4 col6" >0.6269</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8c0c_row5_col0" class="data row5 col0" >0.8936</td>
#       <td id="T_c8c0c_row5_col1" class="data row5 col1" >0.9167</td>
#       <td id="T_c8c0c_row5_col2" class="data row5 col2" >0.9714</td>
#       <td id="T_c8c0c_row5_col3" class="data row5 col3" >0.8947</td>
#       <td id="T_c8c0c_row5_col4" class="data row5 col4" >0.9315</td>
#       <td id="T_c8c0c_row5_col5" class="data row5 col5" >0.6952</td>
#       <td id="T_c8c0c_row5_col6" class="data row5 col6" >0.7071</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8c0c_row6_col0" class="data row6 col0" >0.9574</td>
#       <td id="T_c8c0c_row6_col1" class="data row6 col1" >0.9690</td>
#       <td id="T_c8c0c_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_c8c0c_row6_col3" class="data row6 col3" >0.9459</td>
#       <td id="T_c8c0c_row6_col4" class="data row6 col4" >0.9722</td>
#       <td id="T_c8c0c_row6_col5" class="data row6 col5" >0.8816</td>
#       <td id="T_c8c0c_row6_col6" class="data row6 col6" >0.8879</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8c0c_row7_col0" class="data row7 col0" >0.8723</td>
#       <td id="T_c8c0c_row7_col1" class="data row7 col1" >0.8595</td>
#       <td id="T_c8c0c_row7_col2" class="data row7 col2" >0.9714</td>
#       <td id="T_c8c0c_row7_col3" class="data row7 col3" >0.8718</td>
#       <td id="T_c8c0c_row7_col4" class="data row7 col4" >0.9189</td>
#       <td id="T_c8c0c_row7_col5" class="data row7 col5" >0.6230</td>
#       <td id="T_c8c0c_row7_col6" class="data row7 col6" >0.6437</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c8c0c_row8_col0" class="data row8 col0" >0.7660</td>
#       <td id="T_c8c0c_row8_col1" class="data row8 col1" >0.9167</td>
#       <td id="T_c8c0c_row8_col2" class="data row8 col2" >0.8571</td>
#       <td id="T_c8c0c_row8_col3" class="data row8 col3" >0.8333</td>
#       <td id="T_c8c0c_row8_col4" class="data row8 col4" >0.8451</td>
#       <td id="T_c8c0c_row8_col5" class="data row8 col5" >0.3672</td>
#       <td id="T_c8c0c_row8_col6" class="data row8 col6" >0.3678</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c8c0c_row9_col0" class="data row9 col0" >0.8085</td>
#       <td id="T_c8c0c_row9_col1" class="data row9 col1" >0.8500</td>
#       <td id="T_c8c0c_row9_col2" class="data row9 col2" >0.8857</td>
#       <td id="T_c8c0c_row9_col3" class="data row9 col3" >0.8611</td>
#       <td id="T_c8c0c_row9_col4" class="data row9 col4" >0.8732</td>
#       <td id="T_c8c0c_row9_col5" class="data row9 col5" >0.4823</td>
#       <td id="T_c8c0c_row9_col6" class="data row9 col6" >0.4831</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_c8c0c_row10_col0" class="data row10 col0" >0.8506</td>
#       <td id="T_c8c0c_row10_col1" class="data row10 col1" >0.9130</td>
#       <td id="T_c8c0c_row10_col2" class="data row10 col2" >0.8952</td>
#       <td id="T_c8c0c_row10_col3" class="data row10 col3" >0.9042</td>
#       <td id="T_c8c0c_row10_col4" class="data row10 col4" >0.8981</td>
#       <td id="T_c8c0c_row10_col5" class="data row10 col5" >0.6141</td>
#       <td id="T_c8c0c_row10_col6" class="data row10 col6" >0.6221</td>
#     </tr>
#     <tr>
#       <th id="T_c8c0c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_c8c0c_row11_col0" class="data row11 col0" >0.0537</td>
#       <td id="T_c8c0c_row11_col1" class="data row11 col1" >0.0398</td>
#       <td id="T_c8c0c_row11_col2" class="data row11 col2" >0.0619</td>
#       <td id="T_c8c0c_row11_col3" class="data row11 col3" >0.0410</td>
#       <td id="T_c8c0c_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# ### Evaluate training performance

# %%
plot_model(tuned_extraTreesClassifier, plot = 'auc')

# %%
plot_model(tuned_extraTreesClassifier, plot='feature')

# %%
plot_model(tuned_extraTreesClassifier, plot = 'confusion_matrix')

# %% [markdown]
# ### Evaluate on unseen data

# %%
final_extraTreesClassifier = finalize_model(tuned_extraTreesClassifier)

# %%
unseen_predictions = predict_model(final_extraTreesClassifier, data=test_df)
class_names=['parkinson', 'normal']
print(classification_report(unseen_predictions['class'].values, unseen_predictions['prediction_label'].values, target_names=class_names,zero_division=0))
cm = skplt.metrics.plot_confusion_matrix(unseen_predictions['class'].values, unseen_predictions['prediction_label'].values, figsize=(8, 8), normalize=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d28f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d28f2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d28f2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d28f2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d28f2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d28f2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d28f2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d28f2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d28f2_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d28f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d28f2_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_d28f2_row0_col1" class="data row0 col1" >0.9342</td>
#       <td id="T_d28f2_row0_col2" class="data row0 col2" >0.9854</td>
#       <td id="T_d28f2_row0_col3" class="data row0 col3" >0.9667</td>
#       <td id="T_d28f2_row0_col4" class="data row0 col4" >0.9508</td>
#       <td id="T_d28f2_row0_col5" class="data row0 col5" >0.9587</td>
#       <td id="T_d28f2_row0_col6" class="data row0 col6" >0.7974</td>
#       <td id="T_d28f2_row0_col7" class="data row0 col7" >0.7981</td>
#     </tr>
#   </tbody>
# </table>
#               precision    recall  f1-score   support
#
#    parkinson       0.87      0.81      0.84        16
#       normal       0.95      0.97      0.96        60
#
#     accuracy                           0.93        76
#    macro avg       0.91      0.89      0.90        76
# weighted avg       0.93      0.93      0.93        76
